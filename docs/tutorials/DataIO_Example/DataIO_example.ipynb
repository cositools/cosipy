# %% [markdown]
# # Example 1: Standard binned analysis
# ### Import the BinnedData class from cosipy

# %%
from cosipy import BinnedData
# Out:
# Welcome to JupyROOT 6.24/06
# /zfs/astrohe/Software/COSIMain/MEGAlib/external/root_v6.24.06/lib/ROOT/_facade.py:150: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   return _orig_ihook(name, *args, **kwds)

# %% [markdown]
# ### Define the BinnedData object
# ### Input parameters are passed from inputs.yaml

# %%
analysis = BinnedData("inputs.yaml")

# %% [markdown]
# ### Make data selections
# ### Selections on time, energy, and ROI are specified in inputs.yaml

# %%
analysis.select_data()
# Out:
# running select_data...
#
#
# **************************************************************************
# *                                                                        *
# *            Mimrec - MEGAlib image reconstruction (and more)            *
# *                                                                        *
# *             This program is part of MEGAlib version 3.99.01            *
# *                (C) by Andreas Zoglauer and contributors                *
# *                                                                        *
# *                      Master reference for MEGAlib:                     *
# *            A. Zoglauer et al., NewAR 50 (7-8), 629-632, 2006           *
# *                                                                        *
# *            For more information about MEGAlib please visit:            *
# *                        http://megalibtoolkit.com                       *
# *                                                                        *
# **************************************************************************
#
#               You are using a development version of MEGAlib
#
# Command-line parser: Use configuration file /zfs/astrohe/ckarwin/COSI/COSIpy_Tutorial/Git_Updates/cosipy/cosipy/data_io/housekeeping_files/ContinuumResponse_cori_v1v2_nuclearizer_12Det_200812_imaging_atmos_9Det_6deg_10ebins.mimrec.cfg
# Command-line parser: Use this output file name selected_data.inc1.id1.extracted.tra.gz
# Command-line parser: Do not use the gui
# Command-line parser: Changing this configuration value: EventSelections.Source.UsePointSource=false
# Command-line parser: Changing this configuration value: EventSelections.Source.Coordinates=1
# Command-line parser: Changing this configuration value: EventSelections.Source.Longitude=184.56
# Command-line parser: Changing this configuration value: EventSelections.Source.Latitude=-5.78
# Command-line parser: Changing this configuration value: EventSelections.Source.ARM.Max=20
# Command-line parser: Changing this configuration value: EventSelections.TimeMode=0
# Command-line parser: Changing this configuration value: EventSelections.Time.Min=1463444273.9620788
# Command-line parser: Changing this configuration value: EventSelections.Time.Max=1467477144.589052
# Command-line parser: Changing this configuration value: EventSelections.FirstEnergyWindow.Min=0
# Command-line parser: Changing this configuration value: EventSelections.FirstEnergyWindow.Max=5000
# Command-line parser: No X-client or ROOT in batch mode: Using batch mode
#                      If you didn't give a batch command, the program will exit.
# Command-line parser: Use geometry file /zfs/astrohe/ckarwin/My_Class_Library/COSI/Data_Challenge/Input_Files/Geometry_Files/COSI_Balloon_Geometry_9Det/COSI.DetectorHead.geo.setup
# Command-line parser: Use file /zfs/astrohe/ckarwin/COSI/Data_Challenge/Data_Challenge_1/Run_3/Main_Output/Output/GalacticScan.inc1.id1.extracted.tra.gz
# Stage 1 (reading of file(s)) finished after 0.054865 sec
# Stage 2 (evaluating constants and maths) finished after 0.152687 sec
# Stage 3 (evaluating vectors) finished after 0.16089 sec
# Stage 4 (evaluating for loops) finished after 0.300592 sec
# Stage 5 (evaluating random numbers) finished after 0.303073 sec
# Stage 6 (evaluating if clauses + initial maths evaluation) finished after 0.879793 sec
#    *** User Info: "Loading  shields"
# Stage 7 (analyzing primary keywords) finished after 0.931805 sec
# Stage 8 (analyzing "Copies") finished after 0.938378 sec
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
#    ***  Info  ***
# Sensitivity keyword is redundant
# Stage 9 (analyzing all properties) finished after 1.27469 sec
# Stage 10 (generating clones) finished after 1.27541 sec
# Stage 11 (validation & post-processing) finished after 1.82093 sec
# Stage 12 (volume tree optimization) finished after 1.82169 sec
# Geometry BalloonGeometryWithTwelveDetectors loaded!
# Command-line parser: Extracting events...
# Time reader thread slept: 1.05 sec (the thread will most likely sleep during worker thread initialization)
# Extraction file created: selected_data.inc1.id1.extracted.tra.gz

# %% [markdown]
# ### Read the tra file into a data dictionary

# %%
analysis.read_tra()
# Out:
# running read_tra...

# %% [markdown]
# ### Bin the data

# %%
analysis.get_binned_data()
# Out:
# running get_binned_data...
#
#
# Approximate resolution at NSIDE 8 is 7.3 deg

# %% [markdown]
# ### Plot the raw spectrum and lightcurve

# %%
analysis.plot_raw_spectrum()
# Out:
# running plot_raw_spectrum...

# %%
analysis.plot_raw_lightcurve()
# Out:
# running plot_raw_lightcurve...

# %% [markdown]
# # Example 2: Some available options for the standard binned anlaysis
# ### In the previous step we saved the unbinned data to an hdf5 file with the read_tra() method -- as specified in inputs.yaml.
# ### Here we will load the unbinnned data from file instead of running read_tra() again.
# ### We will also make binning plots.

# %%
analysis = BinnedData("inputs.yaml")
analysis.get_binned_data(unbinned_data="unbinned_data.hdf5", make_binning_plots=True)
# Out:
# running get_binned_data...
#
#
# Approximate resolution at NSIDE 8 is 7.3 deg

# %% [markdown]
# ### The get_binned_data method writes the binned data to an hdf5 file.
# ### Here we will load the binnned data from file to make the raw spectrum and lightcurve
# ### We will also save the spectrum and lightcurve to .dat files.

# %%
analysis = BinnedData("inputs.yaml")
analysis.plot_raw_spectrum(binned_data="binned_data.hdf5", write_spec=True)
analysis.plot_raw_lightcurve(binned_data="binned_data.hdf5", write_lc=True)
# Out:
# running plot_raw_spectrum...
# running plot_raw_lightcurve...
