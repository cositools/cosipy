# %% [markdown]
# # Data format and handling

# %% [markdown]
# ## Example 1: Standard binned analysis
# ### Import the BinnedData class from cosipy

# %%
from cosipy import BinnedData
# Out:
# Welcome to JupyROOT 6.24/08
# 05:12:58 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=497526;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=716225;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#48\48]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=125952;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=870165;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#69\69]8;;\
#                   will not be available.
#          WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=262739;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=359496;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py#36\36]8;;\
#                   available
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=213413;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=854783;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=924168;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=441120;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=799801;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=994551;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=691069;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=564193;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of F to 1e-99 because there was a postive transform   ]8;id=91970;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=111953;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py#704\704]8;;\
#          WARNING   We have set the min_value of K to 1e-99 because there was a postive transform   ]8;id=409988;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py\parameter.py]8;;\:]8;id=213314;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/astromodels/core/parameter.py#704\704]8;;\
# 05:12:59 INFO      Starting 3ML!                                                                     ]8;id=362633;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=877372;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#35\35]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=415973;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=893550;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#36\36]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=992409;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=568074;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#37\37]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=905417;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=343253;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#40\40]8;;\
#          WARNING   no display variable set. using backend for graphics without display (agg)         ]8;id=52599;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=255690;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#46\46]8;;\
# /zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: dev is an invalid version and will not be supported in a future release
#   warnings.warn(
#          WARNING   Multinest minimizer not available                                           ]8;id=597415;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=166369;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=651413;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=861301;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
# 05:12:59 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=162551;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=377898;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=634470;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=844480;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=855425;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=427248;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
# 05:13:00 WARNING   No fermitools installed                                              ]8;id=370384;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=422404;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
# 05:13:00 WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=80949;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=751999;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=769291;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=75165;file:///zfs/astrohe/Software/COSIMain_u2/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML

# %% [markdown]
# ### Define the BinnedData object
# ### Input parameters are passed from inputs.yaml

# %%
analysis = BinnedData("inputs.yaml")

# %%
analysis.read_tra()
# Out:
# reading tra file...
# 100%|██████████| 53383576/53383576 [01:28<00:00, 605408.31it/s]

# %% [markdown]
# ### Bin the data

# %%
analysis.get_binned_data()
# Out:
# binning data...
#
# Note: time bins must be equally spaced between min and max time.
# Using time bin size [s]: 59.999957875410715
#
#
# PsiChi binning:
# Approximate resolution at NSIDE 8 is 7.3 deg

# %% [markdown]
# ### Plot the raw spectrum and lightcurve

# %%
# %matplotlib inline 
analysis.get_raw_spectrum()
# Out:
# getting raw spectrum...

# %%
# LC in plot below is normalized to initial time. 
# %matplotlib inline 
analysis.get_raw_lightcurve()
# Out:
# getting raw lightcurve...

# %% [markdown]
# ## Example 2: Some available options for the standard binned anlaysis
# ### In the previous step the unbinned data is saved to an hdf5 file with the read_tra() method.
# ### Here we will load the unbinnned data from file instead of running read_tra() again.
# ### We will also make binning plots.

# %%
# %matplotlib inline 
analysis = BinnedData("inputs.yaml")
analysis.get_binned_data(unbinned_data="unbinned_data.hdf5", make_binning_plots=True)
# Out:
# binning data...
#
# Note: time bins must be equally spaced between min and max time.
# Using time bin size [s]: 59.999957875410715
#
#
# PsiChi binning:
# Approximate resolution at NSIDE 8 is 7.3 deg

# %% [markdown]
# ### The get_binned_data method writes the binned data to an hdf5 file.
# ### We can load this directly to access the binned data histogram object.

# %%
analysis = BinnedData("inputs.yaml")
analysis.load_binned_data_from_hdf5("binned_data.hdf5")

# This is the binned data histogram object:
print(analysis.binned_data) 

# For example, we can project onto the Time axis:
analysis.binned_data.axes["Time"].centers
# Out:
# <histpy.histogram.Histogram object at 0x14a2ae6ead30>
# array([1.83547803e+09, 1.83547809e+09, 1.83547815e+09, 1.83547821e+09,
#        1.83547827e+09, 1.83547833e+09, 1.83547839e+09, 1.83547845e+09,
#        1.83547851e+09, 1.83547857e+09, 1.83547863e+09, 1.83547869e+09,
#        1.83547875e+09, 1.83547881e+09, 1.83547887e+09, 1.83547893e+09,
#        1.83547899e+09, 1.83547905e+09, 1.83547911e+09, 1.83547917e+09,
#        1.83547923e+09, 1.83547929e+09, 1.83547935e+09, 1.83547941e+09,
#        1.83547947e+09, 1.83547953e+09, 1.83547959e+09, 1.83547965e+09,
#        1.83547971e+09, 1.83547977e+09, 1.83547983e+09, 1.83547989e+09,
#        1.83547995e+09, 1.83548001e+09, 1.83548007e+09, 1.83548013e+09,
#        1.83548019e+09, 1.83548025e+09, 1.83548031e+09, 1.83548037e+09,
#        1.83548043e+09, 1.83548049e+09, 1.83548055e+09, 1.83548061e+09,
#        1.83548067e+09, 1.83548073e+09, 1.83548079e+09, 1.83548085e+09,
#        1.83548091e+09, 1.83548097e+09, 1.83548103e+09, 1.83548109e+09,
#        1.83548115e+09, 1.83548121e+09, 1.83548127e+09, 1.83548133e+09,
#        1.83548139e+09, 1.83548145e+09, 1.83548151e+09, 1.83548157e+09,
#        1.83548163e+09, 1.83548169e+09, 1.83548175e+09, 1.83548181e+09,
#        1.83548187e+09, 1.83548193e+09, 1.83548199e+09, 1.83548205e+09,
#        1.83548211e+09, 1.83548217e+09, 1.83548223e+09, 1.83548229e+09,
#        1.83548235e+09, 1.83548241e+09, 1.83548247e+09, 1.83548253e+09,
#        1.83548259e+09, 1.83548265e+09, 1.83548271e+09, 1.83548277e+09,
#        1.83548283e+09, 1.83548289e+09, 1.83548295e+09, 1.83548301e+09,
#        1.83548307e+09, 1.83548313e+09, 1.83548319e+09, 1.83548325e+09,
#        1.83548331e+09, 1.83548337e+09, 1.83548343e+09, 1.83548349e+09,
#        1.83548355e+09, 1.83548361e+09, 1.83548367e+09, 1.83548373e+09,
#        1.83548379e+09, 1.83548385e+09, 1.83548391e+09, 1.83548397e+09,
#        1.83548403e+09, 1.83548409e+09, 1.83548415e+09, 1.83548421e+09,
#        1.83548427e+09, 1.83548433e+09, 1.83548439e+09, 1.83548445e+09,
#        1.83548451e+09, 1.83548457e+09, 1.83548463e+09, 1.83548469e+09,
#        1.83548475e+09, 1.83548481e+09, 1.83548487e+09, 1.83548493e+09,
#        1.83548499e+09, 1.83548505e+09, 1.83548511e+09, 1.83548517e+09])

# %% [markdown]
# ### Here we will load the binnned data from file to make the raw spectrum and lightcurve.
# ### We can also specify the name of the output files.

# %%
analysis.get_raw_spectrum(binned_data="binned_data.hdf5", output_name="crab_spec")
analysis.get_raw_lightcurve(binned_data="binned_data.hdf5", output_name="crab_lc")
# Out:
# getting raw spectrum...
# getting raw lightcurve...

# %% [markdown]
# ## Example 3: Combining multiple unbinned data files
# ### When combining data files, first combine the unbinned data, and then bin the combined data.
# ### As a proof of concept, we'll combine the crab data set 3 times, and as a sanity check we can then compare to 3x the actual data.

# %%
# The default output file is writen to combined_unbinned_data.hdf5
analysis = BinnedData("inputs.yaml")
analysis.combine_unbinned_data(["unbinned_data.hdf5","unbinned_data.hdf5","unbinned_data.hdf5"])
# Out:
# adding unbinned_data.hdf5...
#
#
# adding unbinned_data.hdf5...
#
#
# adding unbinned_data.hdf5...

# %% [markdown]
# ### Bin the combined data file:

# %%
analysis.get_binned_data(unbinned_data="combined_unbinned_data.hdf5", output_name="combined_binned_data")
# Out:
# binning data...
#
# Note: time bins must be equally spaced between min and max time.
# Using time bin size [s]: 59.999957875410715
#
#
# PsiChi binning:
# Approximate resolution at NSIDE 8 is 7.3 deg

# %% [markdown]
# ### Get raw spectrum and light curve:

# %%
# %matplotlib inline 
analysis.get_raw_spectrum(binned_data="combined_binned_data.hdf5", output_name="crab_spec_3x")
analysis.get_raw_lightcurve(binned_data="combined_binned_data.hdf5", output_name="crab_lc_3x")
# Out:
# getting raw spectrum...
# getting raw lightcurve...

# %% [markdown]
# ### Compare the combined data set to 3x the actual data:
# ### This step requires output files from earlier.

# %%
# LCs: 
# The plots below are normalized to the initial time.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# LCs:
df = pd.read_csv("crab_lc.dat", delim_whitespace=True)
plt.semilogy(df["Time[UTC]"] - df["Time[UTC]"][0], df["Rate[ct/s]"],label="Crab")
plt.semilogy(df["Time[UTC]"] - df["Time[UTC]"][0], 3*df["Rate[ct/s]"],label="3xCrab")

df = pd.read_csv("crab_lc_3x.dat", delim_whitespace=True)
plt.semilogy(df["Time[UTC]"] - df["Time[UTC]"][0], df["Rate[ct/s]"],ls="--",label="Combined")

plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("ct/s")
plt.savefig("combined_lc_comparison.pdf")
plt.show()

# %%
# Spectrum
df = pd.read_csv("crab_spec.dat", delim_whitespace=True)
plt.loglog(df["Energy[keV]"],df["Rate[ct/keV]"],label="Crab")
plt.loglog(df["Energy[keV]"],3*df["Rate[ct/keV]"],label="3xCrab")

df = pd.read_csv("crab_spec_3x.dat", delim_whitespace=True)
plt.loglog(df["Energy[keV]"],df["Rate[ct/keV]"],ls="--",label="Combined")

plt.legend()
plt.xlabel("Energy [keV]")
plt.ylabel("ct/keV")
plt.savefig("combined_spectrum_comparison.pdf")
plt.show()

# %% [markdown]
# ## Example 4: Making data selections.
# ### Only time cuts are available for now.
# ### The parameters tmin and tmax are passed from the yaml file.
# ### In this example we will select the first half of the data set.

# %%
# Output is writen to selected_unbinned_data.hdf5 by default. 
analysis = BinnedData("inputs.yaml")
analysis.select_data(unbinned_data="combined_unbinned_data.hdf5")

# %% [markdown]
# ### Bin the selected data

# %%
analysis.get_binned_data(unbinned_data="selected_unbinned_data.hdf5", output_name="selected_combined_binned_data")
# Out:
# binning data...
#
# Note: time bins must be equally spaced between min and max time.
# Using time bin size [s]: 59.99993039766947
#
#
# PsiChi binning:
# Approximate resolution at NSIDE 8 is 7.3 deg

# %%
# %matplotlib inline 
analysis.get_raw_spectrum(binned_data="selected_combined_binned_data.hdf5", output_name="selected_crab_spec_3x")
analysis.get_raw_lightcurve(binned_data="selected_combined_binned_data.hdf5", output_name="selected_crab_lc_3x")
# Out:
# getting raw spectrum...
# getting raw lightcurve...

# %% [markdown]
# ### Compare to the full data set:

# %%
# LCs: 
# The plots below are normalized to the initial time.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("crab_lc_3x.dat", delim_whitespace=True)
plt.semilogy(df["Time[UTC]"] - df["Time[UTC]"][0], df["Rate[ct/s]"],ls="-",label="Combined")

df = pd.read_csv("selected_crab_lc_3x.dat", delim_whitespace=True)
plt.semilogy(df["Time[UTC]"] - df["Time[UTC]"][0], df["Rate[ct/s]"],ls="--",label="Selected Combined")

plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("ct/s")
plt.savefig("combined_lc_comparison.pdf")
plt.show()

# %%
# Spectrum
df = pd.read_csv("crab_spec_3x.dat", delim_whitespace=True)
plt.loglog(df["Energy[keV]"],df["Rate[ct/keV]"],ls="-",label="Combined")

df = pd.read_csv("selected_crab_spec_3x.dat", delim_whitespace=True)
plt.loglog(df["Energy[keV]"],df["Rate[ct/keV]"],ls="--",label="Selected Combined")

plt.legend()
plt.xlabel("Energy [keV]")
plt.ylabel("ct/keV")
plt.savefig("combined_spectrum_comparison.pdf")
plt.show()
